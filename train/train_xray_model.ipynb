# %%
pip install medmnist
# Out:
# Requirement already satisfied: medmnist in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.0.2)
# Requirement already satisfied: numpy in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from medmnist) (2.3.4)
# Requirement already satisfied: pandas in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from medmnist) (2.3.3)
# Requirement already satisfied: scikit-learn in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from medmnist) (1.7.2)
# Requirement already satisfied: scikit-image in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from medmnist) (0.26.0)
# Requirement already satisfied: tqdm in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from medmnist) (4.67.1)
# Requirement already satisfied: Pillow in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from medmnist) (12.0.0)
# Requirement already satisfied: fire in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from medmnist) (0.7.1)
# Requirement already satisfied: torch in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from medmnist) (2.12.0)
# Requirement already satisfied: torchvision in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from medmnist) (0.27.0)
# Requirement already satisfied: termcolor in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from fire->medmnist) (3.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas->medmnist) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas->medmnist) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas->medmnist) (2025.2)
# Requirement already satisfied: six>=1.5 in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.8.2->pandas->medmnist) (1.17.0)
# Requirement already satisfied: scipy>=1.11.4 in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-image->medmnist) (1.16.3)
# Requirement already satisfied: networkx>=3.0 in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-image->medmnist) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-image->medmnist) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-image->medmnist) (2026.6.1)
# Requirement already satisfied: packaging>=21 in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-image->medmnist) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-image->medmnist) (0.5)
# Requirement already satisfied: joblib>=1.2.0 in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn->medmnist) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn->medmnist) (3.6.0)
# Requirement already satisfied: filelock in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch->medmnist) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch->medmnist) (4.15.0)
# Requirement already satisfied: setuptools<82 in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch->medmnist) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch->medmnist) (1.14.0)
# Requirement already satisfied: jinja2 in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch->medmnist) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch->medmnist) (2025.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from sympy>=1.13.3->torch->medmnist) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jinja2->torch->medmnist) (3.0.3)
# Requirement already satisfied: colorama in C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tqdm->medmnist) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import medmnist
from medmnist import PneumoniaMNIST

train_dataset = PneumoniaMNIST(split='train', download=True)
test_dataset = PneumoniaMNIST(split='test', download=True)

print("Train Samples:", len(train_dataset))
print("Test Samples:", len(test_dataset))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 4.17M/4.17M [00:14<00:00, 289kB/s]
# Train Samples: 4708
# Test Samples: 624

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Flatten, Dense, Dropout
import numpy as np

# Dataset Load
train_dataset = PneumoniaMNIST(split='train', download=True)
test_dataset = PneumoniaMNIST(split='test', download=True)

# Convert to numpy
X_train = train_dataset.imgs
y_train = train_dataset.labels

X_test = test_dataset.imgs
y_test = test_dataset.labels

# Normalize
X_train = X_train.astype("float32") / 255.0
X_test = X_test.astype("float32") / 255.0

# Add channel dimension
X_train = np.expand_dims(X_train, axis=-1)
X_test = np.expand_dims(X_test, axis=-1)

# CNN Model
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),

    Dense(128, activation='relu'),
    Dropout(0.3),

    Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# C:\Users\pande\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 26, 26, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 13, 13, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 11, 11, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 5, 5, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 1600)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         204,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 223,873 (874.50 KB)
#  Trainable params: 223,873 (874.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    epochs=20,
    batch_size=32
)
# Out:
# Epoch 1/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 0.7966 - loss: 0.4482 - val_accuracy: 0.9172 - val_loss: 0.2131
# Epoch 2/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9012 - loss: 0.2286 - val_accuracy: 0.9331 - val_loss: 0.1628
# Epoch 3/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.9318 - loss: 0.1722 - val_accuracy: 0.9469 - val_loss: 0.1437
# Epoch 4/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.9418 - loss: 0.1529 - val_accuracy: 0.9448 - val_loss: 0.1277
# Epoch 5/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.9503 - loss: 0.1411 - val_accuracy: 0.9501 - val_loss: 0.1362
# Epoch 6/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9480 - loss: 0.1449 - val_accuracy: 0.9512 - val_loss: 0.1255
# Epoch 7/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.9525 - loss: 0.1238 - val_accuracy: 0.9512 - val_loss: 0.1090
# Epoch 8/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9506 - loss: 0.1307 - val_accuracy: 0.9522 - val_loss: 0.1077
# Epoch 9/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.9570 - loss: 0.1127 - val_accuracy: 0.9575 - val_loss: 0.1095
# Epoch 10/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.9551 - loss: 0.1180 - val_accuracy: 0.9565 - val_loss: 0.0971
# Epoch 11/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.9623 - loss: 0.1069 - val_accuracy: 0.9565 - val_loss: 0.1016
# Epoch 12/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.9594 - loss: 0.1060 - val_accuracy: 0.9597 - val_loss: 0.0928
# Epoch 13/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.9612 - loss: 0.1014 - val_accuracy: 0.9575 - val_loss: 0.0946
# Epoch 14/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.9642 - loss: 0.0941 - val_accuracy: 0.9628 - val_loss: 0.0821
# Epoch 15/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.9673 - loss: 0.0953 - val_accuracy: 0.9575 - val_loss: 0.0907
# Epoch 16/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.9705 - loss: 0.0891 - val_accuracy: 0.9628 - val_loss: 0.0796
# Epoch 17/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9681 - loss: 0.0824 - val_accuracy: 0.9607 - val_loss: 0.0835
# Epoch 18/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - accuracy: 0.9673 - loss: 0.0892 - val_accuracy: 0.9660 - val_loss: 0.0798
# Epoch 19/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.9734 - loss: 0.0807 - val_accuracy: 0.9650 - val_loss: 0.0751
# Epoch 20/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.9708 - loss: 0.0786 - val_accuracy: 0.9650 - val_loss: 0.0794

# %%
loss, accuracy = model.evaluate(X_test, y_test)

print("Accuracy:", accuracy * 100)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8798 - loss: 0.4635
# Accuracy: 87.9807710647583

# %%
model.save("xray_model.keras")

print("✅ Model Saved Successfully")
# Out:
# ✅ Model Saved Successfully

# %%
from tensorflow.keras.models import load_model

model = load_model("../models/xray_model.keras")

print(model.input_shape)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# (None, 28, 28, 1)

# %%
from tensorflow.keras.models import load_model

model = load_model("../models/xray_model.keras")

print(model.output_shape)
# Out:
# (None, 1)

# %%
from tensorflow.keras.models import load_model

model = load_model("../models/xray_model.keras")

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 26, 26, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 13, 13, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 11, 11, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 5, 5, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 1600)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         204,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 671,621 (2.56 MB)
#  Trainable params: 223,873 (874.50 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 447,748 (1.71 MB)

# %%
print("Input Shape :", model.input_shape)
print("Output Shape:", model.output_shape)
# Out:
# Input Shape : (None, 28, 28, 1)
# Output Shape: (None, 1)

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np

model = load_model("../models/xray_model.keras")

img = image.load_img(
    "F0375525-Healthy_chest,_X-ray.jpg",
    color_mode="grayscale",
    target_size=(28,28)
)

img = image.img_to_array(img)/255.0
img = np.expand_dims(img, axis=0)

pred = model.predict(img)

print(pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step
# [[0.00311283]]
